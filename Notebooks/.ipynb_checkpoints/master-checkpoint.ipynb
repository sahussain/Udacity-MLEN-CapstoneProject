# %% [markdown]
# # Machine Learning Engineer Nanodegree: Forecasting COVID-19 Cases – A `Time Series Forecasting` Model

# %% [markdown]
# ### Domain Background
# On December 31, 2019, the World Health Organization (WHO) was informed of an outbreak of “pneumonia of unknown cause” detected in Wuhan City, Hubei Province, China. Identified as coronavirus disease 2019, it quickly came to be known as COVID-19 and has resulted in an ongoing global pandemic. As of 20 June 2020, more than 8.74 million cases have been reported across 188 countries and territories, resulting in more than 462,000 deaths. More
# than 4.31 million people have recovered.[^1]
#
# In response to this ongoing public health emergency, Johns Hopkins University (JHU), a private research university in Maryland, USA, developed an interactive web-based dashboard hosted by their Center for Systems Science and Engineering (CSSE). The dashboard visualizes and tracks reported cases in real-time, illustrating the location and number of confirmed COVID-19 cases, deaths and recoveries for all affected countries. It is used by researchers, public health authorities, news
# agencies and the general public. All the data collected and displayed is made freely available in a [GitHub repository](https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data).
#
# ### Problem Statement
# This project seeks to forecast number of people infected and number of deaths caused by COVID-19 for a time duration of 14-days based on
# historical data from JHU. I will be using Amazon SageMaker DeepAR forecasting algorithm, a supervised learning algorithm for forecasting
# scalar (one-dimensional) time series using recurrent neural networks (RNN) to produce both point and probabilistic forecasts[^2].
# DeepAR is an underutilized approach in this area.[^3] The dataset contains hundreds of related time series, and DeepAR outperforms classical
# forecasting methods including but not limited to autoregressive integrated moving average (ARIMA), exponential smoothing (ETS), Time Series
# Forecasting with Linear Learner for this type of applications. I will be using [DeepAR](https://github.com/sahussain/ML_SageMaker_Studies/blob/master/Time_Series_Forecasting/Energy_Consumption_Solution.ipynb) and [Time Series Forecasting with Linear Learner](https://github.com/awslabs/amazon-sagemaker-examples/blob/80333fd4632cf6d924d0b91c33bf80da3bdcf926/introduction_to_applying_machine_learning/linear_time_series_forecast/linear_time_series_forecast.ipynb)
#
# -----------
# [^1]:[COVID-19 Dashboard](https://systems.jhu.edu/research/public-health/ncov/) by the Center for Systems Science and Engineering (CSSE) at Johns Hopkins University (JHU)". ArcGIS. Johns Hopkins University. Retrieved 20 June 2020.
#
# [^2]:[DeepAR Forecasting Algorithm. Amazon Web Services](https://docs.aws.amazon.com/sagemaker/latest/dg/deepar.html). Retrieved 20 June, 2020
#
# [^3]:[Time series prediction](https://www.telesens.co/2019/06/08/time-series-prediction/). Telesens. Retrieved 20 June, 2020.

# %% [markdown]
# -----------

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### Loading in the resources.

# %%
#General
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import time
import json # import json for formatting data
import os # os for saving
import io
from urllib.request import urlretrieve
import sys
import random
from datetime import datetime

# Define IAM role
import boto3
import re
from sagemaker import get_execution_role

# for both DeepAR & Linear Learner
from sagemaker.amazon.amazon_estimator import get_image_uri
import sagemaker
from sagemaker.estimator import Estimator

#for Linear Learner
import sagemaker.amazon.common as smac
from sagemaker.predictor import csv_serializer, json_deserializer

# %% [markdown]
# ### Initialize Global variables

# %%
sagemaker_session = sagemaker.Session()
role = get_execution_role()
bucket = sagemaker_session.default_bucket()
prefix_DeepAR='deepar'
prefix = 'linear'
df_start_date = '2020-01-22'

container_linear_learner = get_image_uri(boto3.Session().region_name,'linear-learner')
container_DeepAR = get_image_uri(boto3.Session().region_name,'forecasting-deepar')

# %% [markdown]
# ### Download function

# %%
def progress_report_hook(count, block_size, total_size):
    mb = int(count * block_size // 1e6)
    if count % 50 == 0:
        sys.stdout.write("\r{} MB downloaded".format(mb))
        sys.stdout.flush()

def download(DATA_HOST, DATA_PATH, FILE_NAME, OVERRIDE=1, reporthook=progress_report_hook):
    if OVERRIDE:
        print("downloading dataset, can take a few minutes depending on your connection")
        urlretrieve(DATA_HOST + DATA_PATH + FILE_NAME, FILE_NAME, reporthook=progress_report_hook)
    else:
        print("File found skipping download")

# %% [markdown]
# ### Clean-up functions

# %%
#convenience function to delete prediction endpoints after we're done with them form udacity
def delete_endpoint(predictor):
        try:
            boto3.client('sagemaker').delete_endpoint(EndpointName=predictor.endpoint)
            print('Deleted {}'.format(predictor.endpoint))
        except:
            print('Already deleted: {}'.format(predictor.endpoint))

# %% [markdown]
# -----------

# %% [markdown]
# ## Load and Explore the Data

# %% [markdown]
# ### Downloading data

# %%
DATA_HOST = "https://raw.githubusercontent.com"
DATA_PATH = "/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/"
FILE_NAME = "time_series_covid19_confirmed_US.csv"

# %%
download(DATA_HOST, DATA_PATH, FILE_NAME,0)
# Out:
# File found skipping download

# %% [markdown]
# ### Loading data into pandas

# %%
csv_file = 'time_series_covid19_confirmed_US.csv'
covid_df = pd.read_csv(csv_file)

# %% [markdown]
# ### Examining the Data

# %%
covid_df.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa             US
# 1  316   GU  GUM    316  66.0    NaN                      Guam             US
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands             US
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico             US
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands             US
#
#        Lat     Long_  ... 6/12/20  6/13/20  6/14/20  6/15/20  6/16/20  \
# 0 -14.2710 -170.1320  ...       0        0        0        0        0
# 1  13.4443  144.7937  ...     183      183      183      185      186
# 2  15.0979  145.6739  ...      30       30       30       30       30
# 3  18.2208  -66.5901  ...    5536     5690     5811     5890     5951
# 4  18.3358  -64.8963  ...      72       72       72       72       72
#
#    6/17/20  6/18/20  6/19/20  6/20/20  6/21/20
# 0        0        0        0        0        0
# 1      188      192      200      222      222
# 2       30       30       30       30       30
# 3     6003     6111     6195     6463     6525
# 4       73       73       73       73       76
#
# [5 rows x 163 columns]

# %%
#Geting colunm names
list(covid_df.columns)
# Out:
# ['UID',
#  'iso2',
#  'iso3',
#  'code3',
#  'FIPS',
#  'Admin2',
#  'Province_State',
#  'Country_Region',
#  'Lat',
#  'Long_',
#  'Combined_Key',
#  '1/22/20',
#  '1/23/20',
#  '1/24/20',
#  '1/25/20',
#  '1/26/20',
#  '1/27/20',
#  '1/28/20',
#  '1/29/20',
#  '1/30/20',
#  '1/31/20',
#  '2/1/20',
#  '2/2/20',
#  '2/3/20',
#  '2/4/20',
#  '2/5/20',
#  '2/6/20',
#  '2/7/20',
#  '2/8/20',
#  '2/9/20',
#  '2/10/20',
#  '2/11/20',
#  '2/12/20',
#  '2/13/20',
://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv)
#
# The file have the same columns:
# * UID - UID = 840 (country code3) + 000XX (state FIPS code). Ranging from
# 8400001 to 84000056.
# * iso2- Officially assigned country code identifiers 2 Chr (US, CA, ...)
# * iso3 - Officially assigned country code identifiers 3 Chr.(USA, CAN,
# ...)
# * code3- country code USA = 840
# * FIPS -Federal Information Processing Standards code that uniquely
# identifies counties within the USA.
# * admin2 - County name. US only.
# * Province_State - The name of the State within the USA.
# * Country_Region - The name of the Country (US).
# * Combined_Key - Province_State + Country_Region
# * Population - Population
# * Number of cases are is columns where each column is a day

# %%
#filter code3 - country code: USA = 840 as the scope of this project is limited to US (excluding territories)
covid_df = covid_df[covid_df.code3 == 840]

# %%
covid_df.head()
# Out:
#         UID iso2 iso3  code3    FIPS   Admin2 Province_State Country_Region  \
# 5  84001001   US  USA    840  1001.0  Autauga        Alabama             US
# 6  84001003   US  USA    840  1003.0  Baldwin        Alabama             US
# 7  84001005   US  USA    840  1005.0  Barbour        Alabama             US
# 8  84001007   US  USA    840  1007.0     Bibb        Alabama             US
# 9  84001009   US  USA    840  1009.0   Blount        Alabama             US
#
#          Lat      Long_  ... 6/12/20  6/13/20  6/14/20  6/15/20  6/16/20  \
# 5  32.539527 -86.644082  ...     323      331      357      364      367
# 6  30.727750 -87.722071  ...     353      361      364      368      374
# 7  31.868263 -85.387129  ...     221      226      234      237      244
# 8  32.996421 -87.125115  ...      97      100      104      108      113
# 9  33.982109 -86.567906  ...      95      102      110      114      119
#
#    6/17/20  6/18/20  6/19/20  6/20/20  6/21/20
# 5      369      394      405      425      428
# 6      377      386      398      405      415
# 7      250      262      265      271      271
# 8      115      118      123      123      124
# 9      121      127      136      140      146
#
# [5 rows x 163 columns]

# %%
covid_df.describe()
# Out:
#                 UID   code3          FIPS          Lat        Long_  \
# count  3.256000e+03  3256.0   3246.000000  3256.000000  3256.000000
# mean   8.403226e+07   840.0  32140.254775    37.207365   -89.293868
# std    1.789031e+04     0.0  17794.472586     8.590527    20.708954
# min    8.400100e+07   840.0   1001.000000     0.000000  -164.035380
# 25%    8.401905e+07   840.0  19045.500000    34.256081   -98.066814
# 50%    8.403006e+07   840.0  30050.000000    38.162993   -89.900575
# 75%    8.404703e+07   840.0  47012.500000    41.683958   -82.815121
# max    8.410000e+07   840.0  99999.000000    69.314792     0.000000
#
#            1/22/20      1/23/20      1/24/20      1/25/20      1/26/20  ...  \
# count  3256.000000  3256.000000  3256.000000  3256.000000  3256.000000  ...
# mean      0.000307     0.000307     0.000614     0.000614     0.001536  ...
# std       0.017525     0.017525     0.024780     0.024780     0.039163  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# max       1.000000     1.000000     1.000000     1.000000     1.000000  ...
#
#              6/12/20        6/13/20        6/14/20        6/15/20  \
# count    3256.000000    3256.000000    3256.000000    3256.000000
# mean      627.507678     635.304361     641.345516     647.373771
# std      4639.161611    4662.598323    4679.459914    4696.074559
# min         0.000000       0.000000       0.000000       0.000000
# 25%         9.000000       9.000000      10.000000      10.000000
# 50%        47.000000      48.000000      49.000000      50.000000
# 75%       220.000000     226.000000     228.250000     231.000000
# max    208954.000000  209493.000000  209878.000000  210259.000000
#
#              6/16/20        6/17/20        6/18/20        6/19/20  \
# count    3256.000000    3256.000000    3256.000000    3256.000000
# mean      654.635135     662.468059     670.960074     680.614558
# std      4716.341185    4740.573048    4760.925945    4786.073248
# min         0.000000       0.000000       0.000000       0.000000
# 25%        10.000000      11.000000      11.000000      11.000000
# 50%        51.000000      52.000000      53.000000      54.000000
# 75%       236.000000     238.000000     243.000000     247.000000
# max    210591.000000  210941.000000  211260.000000  211670.000000
#
#              6/20/20        6/21/20
# count    3256.000000    3256.000000
# mean      690.519349     698.103808
# std      4815.692101    4840.806926
# min         0.000000       0.000000
# 25%        12.000000      12.000000
# 50%        55.000000      56.000000
# 75%       253.000000     258.000000
# max    212061.000000  212446.000000
#
# [8 rows x 157 columns]

# %% [markdown]
# ### pivot the dates into a date and cases column

# %%
meta_data = ['UID',
 'iso2',
 'iso3',
 'code3',
 'FIPS',
 'Admin2',
 'Province_State',
 'Country_Region',
 'Lat',
 'Long_',
 'Combined_Key']

covid_df = covid_df.melt(id_vars=meta_data, var_name='Date', value_name='Cases')

# %%
covid_df.head()
# Out:
#         UID iso2 iso3  code3    FIPS   Admin2 Province_State Country_Region  \
# 0  84001001   US  USA    840  1001.0  Autauga        Alabama             US
# 1  84001003   US  USA    840  1003.0  Baldwin        Alabama             US
# 2  84001005   US  USA    840  1005.0  Barbour        Alabama             US
# 3  84001007   US  USA    840  1007.0     Bibb        Alabama             US
# 4  84001009   US  USA    840  1009.0   Blount        Alabama             US
#
#          Lat      Long_          Combined_Key     Date  Cases
# 0  32.539527 -86.644082  Autauga, Alabama, US  1/22/20      0
# 1  30.727750 -87.722071  Baldwin, Alabama, US  1/22/20      0
# 2  31.868263 -85.387129  Barbour, Alabama, US  1/22/20      0
# 3  32.996421 -87.125115     Bibb, Alabama, US  1/22/20      0
# 4  33.982109 -86.567906   Blount, Alabama, US  1/22/20      0

# %% [markdown]
# ### getting rid of unnecessary columns, we only need the 'Combined_Key','Date','Case' columns

# %%
# we only need the 'Combined_Key','Date','Case'
keep_columns = ['Combined_Key','Date','Cases']

covid_df = covid_df.filter(items=keep_columns)

# %%
covid_df.head()
# Out:
#            Combined_Key     Date  Cases
# 0  Autauga, Alabama, US  1/22/20      0
# 1  Baldwin, Alabama, US  1/22/20      0
# 2  Barbour, Alabama, US  1/22/20      0
# 3     Bibb, Alabama, US  1/22/20      0
# 4   Blount, Alabama, US  1/22/20      0

# %% [markdown]
# ### Convert Date which is now a string into a date fromat

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494912 entries, 0 to 494911
# Data columns (total 3 columns):
# Combined_Key    494912 non-null object
# Date            494912 non-null object
# Cases           494912 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 11.3+ MB

# %%
covid_df['Date']= pd.to_datetime(covid_df['Date'])

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494912 entries, 0 to 494911
# Data columns (total 3 columns):
# Combined_Key    494912 non-null object
# Date            494912 non-null datetime64[ns]
# Cases           494912 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 11.3+ MB

# %% [markdown]
# ### Adding time
#
# Eventhough we don't need time, I am just adding this to make this code a bit generic so that if the future we have a column with time

# %%
# adding a Updated time column
covid_df['Time'] = '23:59'

# %%
covid_df.Time = pd.to_timedelta(covid_df.Time + ':00', unit='h') #converting string time to time

# %%
#Before:
covid_df.head()
# Out:
#            Combined_Key       Date  Cases     Time
# 0  Autauga, Alabama, US 2020-01-22      0 23:59:00
# 1  Baldwin, Alabama, US 2020-01-22      0 23:59:00
# 2  Barbour, Alabama, US 2020-01-22      0 23:59:00
# 3     Bibb, Alabama, US 2020-01-22      0 23:59:00
# 4   Blount, Alabama, US 2020-01-22      0 23:59:00

# %%
### Adding Date+Time as index
covid_df.index = covid_df.Date + covid_df.Time

# %%
#After:
covid_df.head()
# Out:
#                              Combined_Key       Date  Cases     Time
# 2020-01-22 23:59:00  Autauga, Alabama, US 2020-01-22      0 23:59:00
# 2020-01-22 23:59:00  Baldwin, Alabama, US 2020-01-22      0 23:59:00
# 2020-01-22 23:59:00  Barbour, Alabama, US 2020-01-22      0 23:59:00
# 2020-01-22 23:59:00     Bibb, Alabama, US 2020-01-22      0 23:59:00
# 2020-01-22 23:59:00   Blount, Alabama, US 2020-01-22      0 23:59:00

# %%
covid_df.index.name = 'Date-Time' #changing index to datetime

# %%
#Drop date and time column
covid_df = covid_df.drop('Time', axis=1)
covid_df = covid_df.drop('Date', axis=1)

# %% [markdown]
# ### Now we have a clean dataset

# %%
covid_df.head()
# Out:
#                              Combined_Key  Cases
# Date-Time
# 2020-01-22 23:59:00  Autauga, Alabama, US      0
# 2020-01-22 23:59:00  Baldwin, Alabama, US      0
# 2020-01-22 23:59:00  Barbour, Alabama, US      0
# 2020-01-22 23:59:00     Bibb, Alabama, US      0
# 2020-01-22 23:59:00   Blount, Alabama, US      0

# %%
print(covid_df.shape)
# Out:
# (494912, 2)

# %%
covid_df.describe()
# Out:
#                Cases
# count  494912.000000
# mean      219.268060
# std      2709.739652
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%        27.000000
# max    212446.000000

# %% [markdown]
# -----------

# %% [markdown]
# ## Helper functions

# %%
def get_all_cities(df):
    return df.filter(items=['Combined_Key'])['Combined_Key'].unique()

def days_between(d2):
    d1 = datetime.strptime(df_start_date, "%Y-%m-%d")
    d2 = datetime.strptime(d2, "%Y-%m-%d")
    return abs((d2 - d1).days)

def getCasesforCity(df, city):
    Cases_City = (df[df.Combined_Key == city]).filter(items=['Date','Cases'])
    returnCases = Cases_City['Cases'].copy()
    return returnCases

def getDFforCity(df, city):
    return (df[df.Combined_Key == city]).filter(items=['Date','Cases'])

def getCasesforCityAsTS(df, city, start_Date, freq='D'):
    city_df = getCasesforCity(df, city)
    #print(city_df)
    city_df = city_df.resample(freq).sum()
    StartRec = days_between(start_Date)
    #print(StartRec, period,len(city_df))
    data = city_df[StartRec:]
    period = len(data)
    #print(data.tail())
    index = pd.date_range(start=start_Date, periods=period, freq=freq)
    #print(index)
    time_series = pd.Series(data=data, index=index)
    return time_series

def getRandomCities(lsCities, nCities):
    randomRecord = random.choices(lsCities, k=nCities)
    return randomRecord

def getRandomAsTS(df, nCities, start_Date='2020-01-22'):
    lsCities = get_all_cities(df)
    randomcities = getRandomCities(lsCities, nCities)
    print("Selected cities: ", randomcities)
    time_series = []
    for city in randomcities:
        print("Getting Data for city: ", city)
        data = getCasesforCityAsTS(df, city,start_Date)
        time_series.append(data)
    return time_series, randomcities

def getAllCitiesAsTS(df, start_Date='2020-01-22'):
    lsCities = get_all_cities(df)
    #print("Selected cities: ", randomcities)
    time_series = []
    for city in lsCities:
        print("Getting Data for city: ", city)
        data = getCasesforCityAsTS(df, city,start_Date)
        time_series.append(data)
    return time_series, lsCities

def getColourList(nColours):
    Colours = []
    for i in range(nColours):
        Colours.append('#%06X' % random.randint(0, 0xFFFFFF))
    return Colours

def plotRandomCities(df, n=5, start_Date='2020-01-22'):
    colours = getColourList(n)
    ts, cities = getRandomAsTS(df,n,start_Date)
    plt.figure(figsize=(15,8))
    
    for n_ts in range(n):
        ts[n_ts].plot(label=cities[n_ts], linewidth=3, color=colours[n_ts])
    
    plt.legend()
    plt.show()
    

def plotGivenCities(ts, cities, start_Date='2020-01-22'):
    n=len(cities)
    colours = getColourList(n)
    #ts, cities = getRandomAsTS(df,n,start_Date)
    plt.figure(figsize=(15,8))
    
    for n_ts in range(n):
        ts[n_ts].plot(label=cities[n_ts], linewidth=3, color=colours[n_ts])
    
    plt.legend()
    plt.show()

# %% [markdown]
# -----

# %% [markdown]
# ## Plotting the Data

# %%
#lets plot 5 ramdom cityes
plotRandomCities(covid_df,5)
# Out:
# Selected cities:  ['Steuben, Indiana, US', 'Garfield, Montana, US', 'Dane, Wisconsin, US', 'Monroe, Missouri, US', 'Cheshire, New Hampshire, US']
# Getting Data for city:  Steuben, Indiana, US
# Getting Data for city:  Garfield, Montana, US
# Getting Data for city:  Dane, Wisconsin, US
# Getting Data for city:  Monroe, Missouri, US
# Getting Data for city:  Cheshire, New Hampshire, US

# %%
#lets plot 15 cityes
plotRandomCities(covid_df, 15)
# Out:
# Selected cities:  ['Union, Georgia, US', 'Searcy, Arkansas, US', 'Shiawassee, Michigan, US', 'Davidson, Tennessee, US', 'Baltimore City, Maryland, US', 'Saline, Illinois, US', 'Johnston, Oklahoma, US', 'St. Joseph, Michigan, US', 'Unassigned, California, US', 'Johnson, Kentucky, US', 'Hart, Georgia, US', 'Calhoun, Illinois, US', 'Edgefield, South Carolina, US', 'Yazoo, Mississippi, US', 'Grady, Georgia, US']
# Getting Data for city:  Union, Georgia, US
# Getting Data for city:  Searcy, Arkansas, US
# Getting Data for city:  Shiawassee, Michigan, US
# Getting Data for city:  Davidson, Tennessee, US
# Getting Data for city:  Baltimore City, Maryland, US
# Getting Data for city:  Saline, Illinois, US
# Getting Data for city:  Johnston, Oklahoma, US
# Getting Data for city:  St. Joseph, Michigan, US
# Getting Data for city:  Unassigned, California, US
# Getting Data for city:  Johnson, Kentucky, US
# Getting Data for city:  Hart, Georgia, US
# Getting Data for city:  Calhoun, Illinois, US
# Getting Data for city:  Edgefield, South Carolina, US
# Getting Data for city:  Yazoo, Mississippi, US
# Getting Data for city:  Grady, Georgia, US

# %%
#lets start form Apt 1

plotRandomCities(covid_df, 15,'2020-04-01')
# Out:
# Selected cities:  ['Hays, Texas, US', 'Rowan, Kentucky, US', 'Meigs, Ohio, US', 'Taylor, Florida, US', 'Del Norte, California, US', 'Pickens, Georgia, US', 'Dickinson, Iowa, US', 'San Benito, California, US', 'Aiken, South Carolina, US', 'Mitchell, Kansas, US', 'Lincoln, Missouri, US', 'Eaton, Michigan, US', 'Lancaster, South Carolina, US', 'Warren, Pennsylvania, US', 'Walthall, Mississippi, US']
# Getting Data for city:  Hays, Texas, US
# Getting Data for city:  Rowan, Kentucky, US
# Getting Data for city:  Meigs, Ohio, US
# Getting Data for city:  Taylor, Florida, US
# Getting Data for city:  Del Norte, California, US
# Getting Data for city:  Pickens, Georgia, US
# Getting Data for city:  Dickinson, Iowa, US
# Getting Data for city:  San Benito, California, US
# Getting Data for city:  Aiken, South Carolina, US
# Getting Data for city:  Mitchell, Kansas, US
# Getting Data for city:  Lincoln, Missouri, US
# Getting Data for city:  Eaton, Michigan, US
# Getting Data for city:  Lancaster, South Carolina, US
# Getting Data for city:  Warren, Pennsylvania, US
# Getting Data for city:  Walthall, Mississippi, US

# %%
#lets try may 1st
plotRandomCities(covid_df, 15,'2020-05-01')
# Out:
# Selected cities:  ['Crook, Wyoming, US', 'Dickinson, Michigan, US', 'Wabaunsee, Kansas, US', 'Butte, Idaho, US', 'Petersburg, Virginia, US', 'Walworth, Wisconsin, US', 'Larimer, Colorado, US', 'Winston, Mississippi, US', 'Grant, Washington, US', 'Forrest, Mississippi, US', 'Baldwin, Alabama, US', 'Williams, Ohio, US', 'Lafayette, Louisiana, US', 'Jefferson, Louisiana, US', 'Christian, Kentucky, US']
# Getting Data for city:  Crook, Wyoming, US
# Getting Data for city:  Dickinson, Michigan, US
# Getting Data for city:  Wabaunsee, Kansas, US
# Getting Data for city:  Butte, Idaho, US
# Getting Data for city:  Petersburg, Virginia, US
# Getting Data for city:  Walworth, Wisconsin, US
# Getting Data for city:  Larimer, Colorado, US
# Getting Data for city:  Winston, Mississippi, US
# Getting Data for city:  Grant, Washington, US
# Getting Data for city:  Forrest, Mississippi, US
# Getting Data for city:  Baldwin, Alabama, US
# Getting Data for city:  Williams, Ohio, US
# Getting Data for city:  Lafayette, Louisiana, US
# Getting Data for city:  Jefferson, Louisiana, US
# Getting Data for city:  Christian, Kentucky, US

# %% [markdown]
# -----------

# %% [markdown]
# ## I have a promble
#
# When looking at the data the dataset only have data for the last 151 days and I can see that out of which starting Apr 1, 2020 is somthing
# good we can use.
#
# I can not use DeepAR on this data because DeepAR needs at least 300 observations available across all training time series and we have at most 151.
#
# >We recommend training a DeepAR model on as many time series as are available. Although a DeepAR model trained on a single time series might work well, standard forecasting algorithms, such as ARIMA or ETS, might provide more accurate results. The DeepAR algorithm starts to outperform the standard methods when your dataset contains hundreds of related time series. Currently, DeepAR requires that the total number of observations available across all training time series is at least 300.
# Source: https://docs.aws.amazon.com/sagemaker/latest/dg/deepar.html

# %% [markdown]
# ## Exploring other options:
# Maybe I can use other `Time Series Forecasting Model(TSFMs)`

# %% [markdown]
# ## Researching (TSFMs)
#
# ***AR (autoregressive model):***
# The autoregression (AR) method models the next step in the sequence as a linear function of the observations at prior time steps.
# The notation for the model involves specifying the order of the model p as a parameter to the AR function, e.g. AR(p). For example, AR(1) is a first-order autoregression model.
# The method is suitable for univariate time series without trend and seasonal components.[^1]
#
# ***MA (moving-average model):***
# The moving average (MA) method models the next step in the sequence as a linear function of the residual errors from a mean process at prior time steps.
# A moving average model is different from calculating the moving average of the time series.
# The notation for the model involves specifying the order of the model q as a parameter to the MA function, e.g. MA(q). For example, MA(1) is a first-order moving average model.
# The method is suitable for univariate time series without trend and seasonal components.[^1]
#
# ***ARMA (autoregressive-moving-average model):***
# The Autoregressive Moving Average (ARMA) method models the next step in the sequence as a linear function of the observations and resiudal errors at prior time steps.
# It combines both Autoregression (AR) and Moving Average (MA) models.
# The notation for the model involves specifying the order for the AR(p) and MA(q) models as parameters to an ARMA function, e.g. ARMA(p, q). An ARIMA model can be used to develop AR or MA models.
# The method is suitable for univariate time series without trend and seasonal components.[^1]
#
# ***ARIMA (autoregressive integrated moving average model):***
# The Autoregressive Integrated Moving Average (ARIMA) method models the next step in the sequence as a linear function of the differenced observations and residual errors at prior time steps.
# It combines both Autoregression (AR) and Moving Average (MA) models as well as a differencing pre-processing step of the sequence to make the sequence stationary, called integration (I).
# The notation for the model involves specifying the order for the AR(p), I(d), and MA(q) models as parameters to an ARIMA function, e.g. ARIMA(p, d, q). An ARIMA model can also be used to develop AR, MA, and ARMA models.
# The method is suitable for univariate time series with trend and without seasonal components.[^1]
#
# ***SARIMA (seasonal autoregressive integrated moving average model):***
# The  [Seasonal Autoregressive Integrated Moving Average (SARIMA)](https://machinelearningmastery.com/sarima-for-time-series-forecasting-in-python/)  method models the next step in the sequence as a linear function of the differenced observations, errors, differenced seasonal observations, and seasonal errors at prior time steps.
# It combines the ARIMA model with the ability to perform the same autoregression, differencing, and moving average modeling at the seasonal level.
# The notation for the model involves specifying the order for the AR(p), I(d), and MA(q) models as parameters to an ARIMA function and AR(P), I(D), MA(Q) and m parameters at the seasonal level, e.g. SARIMA(p, d, q)(P, D, Q)m where “m” is the number of time steps in each season (the seasonal period). A SARIMA model can be used to develop AR, MA, ARMA and ARIMA models.
# The method is suitable for univariate time series with trend and/or seasonal components.[^1]
#
# ***SARIMAX (seasonal autoregressive integrated moving average model with exogenous variables):***
# The Seasonal Autoregressive Integrated Moving-Average with Exogenous Regressors ([SARIMAX](https://machinelearningmastery.com/sarima-for-time-series-forecasting-in-python/)) is an extension of the SARIMA model that also includes the modeling of exogenous variables.
# Exogenous variables are also called covariates and can be thought of as parallel input sequences that have observations at the same time steps as the original series. The primary series may be referred to as endogenous data to contrast it from the exogenous sequence(s). The observations for exogenous variables are included in the model directly at each time step and are not modeled in the same way as the primary endogenous sequence (e.g. as an AR, MA, etc. process).
# The SARIMAX method can also be used to model the subsumed models with exogenous variables, such as ARX, MAX, ARMAX, and ARIMAX.
# The method is suitable for univariate time series with trend and/or seasonal components and exogenous variables.[^1]
#
# ***VARMA (vector autoregressive moving average model):***
# The Vector Autoregression Moving-Average (VARMA) method models the next step in each time series using an ARMA model. It is the generalization of ARMA to multiple parallel time series, e.g. multivariate time series.
# The notation for the model involves specifying the order for the AR(p) and MA(q) models as parameters to a VARMA function, e.g. VARMA(p, q). A VARMA model can also be used to develop VAR or VMA models.
# The method is suitable for multivariate time series without trend and seasonal components.[^1]
#
# -----
#
# ***Vector Autoregression (VAR)***
# The Vector Autoregression (VAR) method models the next step in each time series using an AR model. It is the generalization of AR to multiple parallel time series, e.g. multivariate time series.
# The notation for the model involves specifying the order for the AR(p) model as parameters to a VAR function, e.g. VAR(p).
# The method is suitable for multivariate time series without trend and seasonal components.[^1]
#
# ***Vector Autoregression Moving-Average with Exogenous Regressors (VARMAX)***
# The Vector Autoregression Moving-Average with Exogenous Regressors (VARMAX) is an extension of the VARMA model that also includes the modeling of exogenous variables. It is a multivariate version of the ARMAX method.
# Exogenous variables are also called covariates and can be thought of as parallel input sequences that have observations at the same time steps as the original series. The primary series(es) are referred to as endogenous data to contrast it from the exogenous sequence(s). The observations for exogenous variables are included in the model directly at each time step and are not modeled in the same way as the primary endogenous sequence (e.g. as an AR, MA, etc. process).
# The VARMAX method can also be used to model the subsumed models with exogenous variables, such as VARX and VMAX.
# The method is suitable for multivariate time series without trend and seasonal components with exogenous variables.[^1]
#
# ***Simple Exponential Smoothing (SES)***
# The Simple Exponential Smoothing (SES) method models the next time step as an exponentially weighted linear function of observations at prior time steps.
# The method is suitable for univariate time series without trend and seasonal components.[^1]
#
#
# ***Holt Winter’s Exponential Smoothing (HWES)***
#
# The  [Holt Winter’s Exponential Smoothing](https://machinelearningmastery.com/how-to-grid-search-triple-exponential-smoothing-for-time-series-forecasting-in-python/)  (HWES) also called the Triple Exponential Smoothing method models the next time step as an exponentially weighted linear function of observations at prior time steps, taking trends and seasonality into account.
# The method is suitable for univariate time series with trend and/or seasonal components.[^1]
#
# ***ARCH (autoregressive conditional heteroscedasticity model)***
# Autoregressive conditional heteroskedasticity (ARCH) is a time-series statistical model used to analyze effects left unexplained by econometric models. In these models, the error term is the residual result left unexplained by the model. The assumption of econometric models is that the [variance](https://www.investopedia.com/terms/v/variance.asp) of this term will be uniform. This is known as "homoskedasticity." However, in some circumstances, this variance is not uniform, but "heteroskedastic."[^2]
# ***ARIMAX (autoregressive integrated moving average model with exogenous variables)***
# A time series model using the Autoregressive Integrated Moving Average with exogenous variables (ARIMAX) function was developed to predict impacts from groundwater pumping on Silver Springs discharge in Ocala Florida. This effort was conducted to determine the effects of groundwater withdrawal using the statistical relationship between rainfall and spring discharge at Silver Springs. Other statistical models were developed in previous work by both Southwest Florida Water Management Districts and St Johns River Water Management District. However, there were several opportunities for improvement including using consistent data, model calibration period, and residual periods. Additionally previous statistical methods included Multiple Linear Regression and Line of Organic Correlation methods. These methods did not account for autocorrelation that present in many time series analysis. Through inter-district collaboration, data was made consistent and new methods were explored. The ARIMAX model was explored in this paper and is useful for prediction when autoregressive patterns are present in model residuals that bias modeled coefficients.[^3]
# ***GARCH (generalized autoregressive conditional heteroscedasticity model)***
# A natural generalization of the ARCH (Autoregressive Conditional Heteroskedastic) process introduced in Engle (1982) to allow for past conditional variances in the current conditional variance equation is proposed. Stationarity conditions and autocorrelation structure for this new class of parametric models are derived. Maximum likelihood estimation and testing are also considered.[^4]
#
# ***SARIA (seasonal autoregressive moving average model)***
#
#
# ----
# *****Source:*****
#
# [^1]:[11 Classical Time Series Forecasting Methods in Python (Cheat Sheet)](https://machinelearningmastery.com/time-series-forecasting-methods-in-python-cheat-sheet/)
#
# [^2]:[Autoregressive Conditional Heteroskedasticity (ARCH)](https://www.investopedia.com/terms/a/autoregressive-conditional-heteroskedasticity.asp)
#
# [^3]:[Autoregressive Integrated Moving Average Model with exogenous variables (ARIMAX) transfer function model for Sharpes Ferry Well and Silver Springs](https://rstudio-pubs-static.s3.amazonaws.com/180268_8acc87dd9fa2435c8a8e5ed6b815be2c.html)
#
# [^4]:[Generalized autoregressive conditional heteroskedasticity](https://www.sciencedirect.com/science/article/abs/pii/0304407686900631?via%3Dihub)

# %% [markdown]
# -----

# %% [markdown]
# ## Analyzing the data

# %% [markdown]
# ### Checking data for Stationarity
#
# What is `Stationarity`?
# For us to use any of the above menting TSFMs our time-series, We need to first Identfy if the given time-series is `Stationarity`
#
# For a time-series to be Stationarity, the following do not change over time
# 1. mean(μ)
# 2. standard deviation(σ)
# 3. Autocorrelation structure (No seasonality)
#
# for more info see [Stationarity](https://www.itl.nist.gov/div898/handbook/pmc/section4/pmc442.htm)
#
# *** Based on the graphs above we will start the dataset from Apr 1, 2020

# %%
covid_ts, cities_ls = getAllCitiesAsTS(covid_df,'2020-04-01')
# Out:
# Getting Data for city:  Autauga, Alabama, US
# Getting Data for city:  Baldwin, Alabama, US
# Getting Data for city:  Barbour, Alabama, US
# Getting Data for city:  Bibb, Alabama, US
# Getting Data for city:  Blount, Alabama, US
# Getting Data for city:  Bullock, Alabama, US
# Getting Data for city:  Butler, Alabama, US
# Getting Data for city:  Calhoun, Alabama, US
# Getting Data for city:  Chambers, Alabama, US
# Getting Data for city:  Cherokee, Alabama, US
# Getting Data for city:  Chilton, Alabama, US
# Getting Data for city:  Choctaw, Alabama, US
# Getting Data for city:  Clarke, Alabama, US
# Getting Data for city:  Clay, Alabama, US
# Getting Data for city:  Cleburne, Alabama, US
# Getting Data for city:  Coffee, Alabama, US
# Getting Data for city:  Colbert, Alabama, US
# Getting Data for city:  Conecuh, Alabama, US
# Getting Data for city:  Coosa, Alabama, US
# Getting Data for city:  Covington, Alabama, US
# Getting Data for city:  Crenshaw, Alabama, US
# Getting Data for city:  Cullman, Alabama, US
# Getting Data for city:  Dale, Alabama, US
# Getting Data for city:  Dallas, Alabama, US
# Getting Data for city:  DeKalb, Alabama, US
# Getting Data for city:  Elmore, Alabama, US
# Getting Data for city:  Escambia, Alabama, US
# Getting Data for city:  Etowah, Alabama, US
# Getting Data for city:  Fayette, Alabama, US
# Getting Data for city:  Franklin, Alabama, US
# Getting Data for city:  Geneva, Alabama, US
# Getting Data for city:  Greene, Alabama, US
# Getting Data for city:  Hale, Alabama, US
# Getting Data for city:  Henry, Alabama, US
# Getting Data for city:  Houston, Alabama, US
# Getting Data for city:  Jackson, Alabama, US
# Getting Data for city:  Jefferson, Alabama, US
# Getting Data for city:  Lamar, Alabama, US
# Getting Data for city:  Lauderdale, Alabama, US
# Getting Data for city:  Lawrence, Alabama, US
# Getting Data for city:  Lee, Alabama, US
# Getting Data for city:  Limestone, Alabama, US
# Getting Data for city:  Santa Cruz, Arizona, US
# Getting Data for city:  Yavapai, Arizona, US
# Getting Data for city:  Yuma, Arizona, US
# Getting Data for city:  Arkansas, Arkansas, US
# Getting Data for city:  Ashley, Arkansas, US
# Getting Data for city:  Baxter, Arkansas, US
# Getting Data for city:  Benton, Arkansas, US
# Getting Data for city:  Boone, Arkansas, US
# Getting Data for city:  Bradley, Arkansas, US
# Getting Data for city:  Calhoun, Arkansas, US
# Getting Data for city:  Carroll, Arkansas, US
# Getting Data for city:  Chicot, Arkansas, US
# Getting Data for city:  Clark, Arkansas, US
# Getting Data for city:  Clay, Arkansas, US
# Getting Data for city:  Cleburne, Arkansas, US
# Getting Data for city:  Cleveland, Arkansas, US
# Getting Data for city:  Columbia, Arkansas, US
# Getting Data for city:  Conway, Arkansas, US
# Getting Data for city:  Craighead, Arkansas, US
# Getting Data for city:  Crawford, Arkansas, US
# Getting Data for city:  Crittenden, Arkansas, US
# Getting Data for city:  Cross, Arkansas, US
# Getting Data for city:  Dallas, Arkansas, US
# Getting Data for city:  Desha, Arkansas, US
# Getting Data for city:  Drew, Arkansas, US
# Getting Data for city:  Faulkner, Arkansas, US
# Getting Data for city:  Franklin, Arkansas, US
# Getting Data for city:  Fulton, Arkansas, US
# Getting Data for city:  Garland, Arkansas, US
# Getting Data for city:  Grant, Arkansas, US
# Getting Data for city:  Greene, Arkansas, US
# Getting Data for city:  Hempstead, Arkansas, US
# Getting Data for city:  Hot Spring, Arkansas, US
# Getting Data for city:  Howard, Arkansas, US
# Getting Data for city:  Independence, Arkansas, US
# Getting Data for city:  Izard, Arkansas, US
# Getting Data for city:  Jackson, Arkansas, US
# Getting Data for city:  Jefferson, Arkansas, US
# Getting Data for city:  Johnson, Arkansas, US
# Getting Data for city:  Lafayette, Arkansas, US
# Getting Data for city:  Lawrence, Arkansas, US
# Getting Data for city:  Lee, Arkansas, US
# Getting Data for city:  Lincoln, Arkansas, US
# Getting Data for city:  Little River, Arkansas, US
# Getting Data for city:  Logan, Arkansas, US
# Getting Data for city:  Lonoke, Arkansas, US
# Getting Data for city:  Madison, Arkansas, US
# Getting Data for city:  Marion, Arkansas, US
# Getting Data for city:  Miller, Arkansas, US
# Getting Data for city:  Mississippi, Arkansas, US
# Getting Data for city:  Monroe, Arkansas, US
# Getting Data for city:  Montgomery, Arkansas, US
# Getting Data for city:  Nevada, Arkansas, US
# Getting Data for city:  Newton, Arkansas, US
# Getting Data for city:  Ouachita, Arkansas, US
# Getting Data for city:  Perry, Arkansas, US
# Getting Data for city:  Phillips, Arkansas, US
# Getting Data for city:  Pike, Arkansas, US
# Getting Data for city:  Poinsett, Arkansas, US
# Getting Data for city:  Polk, Arkansas, US
# Getting Data for city:  Pope, Arkansas, US
# Getting Data for city:  Prairie, Arkansas, US
# Getting Data for city:  Pulaski, Arkansas, US
# Getting Data for city:  Randolph, Arkansas, US
# Getting Data for city:  St. Francis, Arkansas, US
# Getting Data for city:  Saline, Arkansas, US
# Getting Data for city:  Scott, Arkansas, US
# Getting Data for city:  Searcy, Arkansas, US
# Getting Data for city:  Sebastian, Arkansas, US
# Getting Data for city:  Sevier, Arkansas, US
# Getting Data for city:  Sharp, Arkansas, US
# Getting Data for city:  Stone, Arkansas, US
# Getting Data for city:  Union, Arkansas, US
# Getting Data for city:  Van Buren, Arkansas, US
# Getting Data for city:  Washington, Arkansas, US
# Getting Data for city:  White, Arkansas, US
# Getting Data for city:  Woodruff, Arkansas, US
# Getting Data for city:  Yell, Arkansas, US
# Getting Data for city:  Alameda, California, US
# Getting Data for city:  Alpine, California, US
# Getting Data for city:  Amador, California, US
# Getting Data for city:  Butte, California, US
# Getting Data for city:  Calaveras, California, US
# Getting Data for city:  Colusa, California, US
# Getting Data for city:  Contra Costa, California, US
# Getting Data for city:  Del Norte, California, US
# Getting Data for city:  El Dorado, California, US
# Getting Data for city:  Fresno, California, US
# Getting Data for city:  Glenn, California, US
# Getting Data for city:  Humboldt, California, US
# Getting Data for city:  Imperial, California, US
# Getting Data for city:  Inyo, California, US
# Getting Data for city:  Kern, California, US
# Getting Data for city:  Kings, California, US
# Getting Data for city:  Lake, California, US
# Getting Data for city:  Lassen, California, US
# Getting Data for city:  Los Angeles, California, US
# Getting Data for city:  Madera, California, US
# Getting Data for city:  Marin, California, US
# Getting Data for city:  Mariposa, California, US
# Getting Data for city:  Mendocino, California, US
# Getting Data for city:  Merced, California, US
# Getting Data for city:  Modoc, California, US
# Getting Data for city:  Mono, California, US
# Getting Data for city:  Monterey, California, US
# Getting Data for city:  Napa, California, US
# Getting Data for city:  Nevada, California, US
# Getting Data for city:  Orange, California, US
# Getting Data for city:  Placer, California, US
# Getting Data for city:  Plumas, California, US
# Getting Data for city:  Riverside, California, US
# Getting Data for city:  Sacramento, California, US
# Getting Data for city:  San Benito, California, US
# Getting Data for city:  San Bernardino, California, US
# Getting Data for city:  San Diego, California, US
# Getting Data for city:  San Francisco, California, US
# Getting Data for city:  San Joaquin, California, US
# Getting Data for city:  San Luis Obispo, California, US
# Getting Data for city:  San Mateo, California, US
# Getting Data for city:  Santa Barbara, California, US
# Getting Data for city:  Santa Clara, California, US
# Getting Data for city:  Santa Cruz, California, US
# Getting Data for city:  Shasta, California, US
# Getting Data for city:  Sierra, California, US
# Getting Data for city:  Siskiyou, California, US
# Getting Data for city:  Solano, California, US
# Getting Data for city:  Sonoma, California, US
# Getting Data for city:  Stanislaus, California, US
# Getting Data for city:  Sutter, California, US
# Getting Data for city:  Tehama, California, US
# Getting Data for city:  Trinity, California, US
# Getting Data for city:  Tulare, California, US
# Getting Data for city:  Tuolumne, California, US
# Getting Data for city:  Ventura, California, US
# Getting Data for city:  Yolo, California, US
# Getting Data for city:  Yuba, California, US
# Getting Data for city:  Adams, Colorado, US
# Getting Data for city:  Alamosa, Colorado, US
# Getting Data for city:  Arapahoe, Colorado, US
# Getting Data for city:  Archuleta, Colorado, US
# Getting Data for city:  Baca, Colorado, US
# Getting Data for city:  Bent, Colorado, US
# Getting Data for city:  Peoria, Illinois, US
# Getting Data for city:  Perry, Illinois, US
# Getting Data for city:  Piatt, Illinois, US
# Getting Data for city:  Pike, Illinois, US
# Getting Data for city:  Pope, Illinois, US
# Getting Data for city:  Pulaski, Illinois, US
# Getting Data for city:  Putnam, Illinois, US
# Getting Data for city:  Randolph, Illinois, US
# Getting Data for city:  Richland, Illinois, US
# Getting Data for city:  Rock Island, Illinois, US
# Getting Data for city:  St. Clair, Illinois, US
# Getting Data for city:  Saline, Illinois, US
# Getting Data for city:  Sangamon, Illinois, US
# Getting Data for city:  Schuyler, Illinois, US
# Getting Data for city:  Scott, Illinois, US
# Getting Data for city:  Shelby, Illinois, US
# Getting Data for city:  Stark, Illinois, US
# Getting Data for city:  Stephenson, Illinois, US
# Getting Data for city:  Tazewell, Illinois, US
# Getting Data for city:  Union, Illinois, US
# Getting Data for city:  Vermilion, Illinois, US
# Getting Data for city:  Wabash, Illinois, US
# Getting Data for city:  Warren, Illinois, US
# Getting Data for city:  Washington, Illinois, US
# Getting Data for city:  Wayne, Illinois, US
# Getting Data for city:  White, Illinois, US
# Getting Data for city:  Whiteside, Illinois, US
# Getting Data for city:  Will, Illinois, US
# Getting Data for city:  Williamson, Illinois, US
# Getting Data for city:  Winnebago, Illinois, US
# Getting Data for city:  Woodford, Illinois, US
# Getting Data for city:  Adams, Indiana, US
# Getting Data for city:  Allen, Indiana, US
# Getting Data for city:  Bartholomew, Indiana, US
# Getting Data for city:  Benton, Indiana, US
# Getting Data for city:  Blackford, Indiana, US
# Getting Data for city:  Boone, Indiana, US
# Getting Data for city:  Brown, Indiana, US
# Getting Data for city:  Carroll,Indiana,US
# Getting Data for city:  Cass, Indiana, US
# Getting Data for city:  Clark, Indiana, US
# Getting Data for city:  Clay, Indiana, US
# Getting Data for city:  Clinton, Indiana, US
# Getting Data for city:  Crawford, Indiana, US
# Getting Data for city:  Daviess, Indiana, US
# Getting Data for city:  Dearborn, Indiana, US
# Getting Data for city:  Decatur, Indiana, US
# Getting Data for city:  DeKalb, Indiana, US
# Getting Data for city:  Delaware, Indiana, US
# Getting Data for city:  Dubois, Indiana, US
# Getting Data for city:  Elkhart, Indiana, US
# Getting Data for city:  Fayette, Indiana, US
# Getting Data for city:  Floyd, Indiana, US
# Getting Data for city:  Fountain, Indiana, US
# Getting Data for city:  Franklin, Indiana, US
# Getting Data for city:  Fulton, Indiana, US
# Getting Data for city:  Gibson, Indiana, US
# Getting Data for city:  Grant, Indiana, US
# Getting Data for city:  Greene, Indiana, US
# Getting Data for city:  Hamilton, Indiana, US
# Getting Data for city:  Hancock, Indiana, US
# Getting Data for city:  Harrison, Indiana, US
# Getting Data for city:  Hendricks, Indiana, US
# Getting Data for city:  Henry, Indiana, US
# Getting Data for city:  Howard, Indiana, US
# Getting Data for city:  Huntington, Indiana, US
# Getting Data for city:  Jackson, Indiana, US
# Getting Data for city:  Jasper, Indiana, US
# Getting Data for city:  Jay, Indiana, US
# Getting Data for city:  Jefferson, Indiana, US
# Getting Data for city:  McPherson, Kansas, US
# Getting Data for city:  Marion, Kansas, US
# Getting Data for city:  Marshall, Kansas, US
# Getting Data for city:  Meade, Kansas, US
# Getting Data for city:  Miami, Kansas, US
# Getting Data for city:  Mitchell, Kansas, US
# Getting Data for city:  Montgomery, Kansas, US
# Getting Data for city:  Morris, Kansas, US
# Getting Data for city:  Morton, Kansas, US
# Getting Data for city:  Nemaha, Kansas, US
# Getting Data for city:  Neosho, Kansas, US
# Getting Data for city:  Ness, Kansas, US
# Getting Data for city:  Norton, Kansas, US
# Getting Data for city:  Osage, Kansas, US
# Getting Data for city:  Osborne, Kansas, US
# Getting Data for city:  Ottawa, Kansas, US
# Getting Data for city:  Pawnee, Kansas, US
# Getting Data for city:  Phillips, Kansas, US
# Getting Data for city:  Pottawatomie, Kansas, US
# Getting Data for city:  Pratt, Kansas, US
# Getting Data for city:  Rawlins, Kansas, US
# Getting Data for city:  Reno, Kansas, US
# Getting Data for city:  Republic, Kansas, US
# Getting Data for city:  Rice, Kansas, US
# Getting Data for city:  Riley, Kansas, US
# Getting Data for city:  Rooks, Kansas, US
# Getting Data for city:  Rush, Kansas, US
# Getting Data for city:  Russell, Kansas, US
# Getting Data for city:  Saline, Kansas, US
# Getting Data for city:  Scott, Kansas, US
# Getting Data for city:  Sedgwick, Kansas, US
# Getting Data for city:  Seward, Kansas, US
# Getting Data for city:  Shawnee, Kansas, US
# Getting Data for city:  Sheridan, Kansas, US
# Getting Data for city:  Sherman, Kansas, US
# Getting Data for city:  Smith, Kansas, US
# Getting Data for city:  Stafford, Kansas, US
# Getting Data for city:  Stanton, Kansas, US
# Getting Data for city:  Stevens, Kansas, US
# Getting Data for city:  Sumner, Kansas, US
# Getting Data for city:  Thomas, Kansas, US
# Getting Data for city:  Trego, Kansas, US
# Getting Data for city:  Wabaunsee, Kansas, US
# Getting Data for city:  Wallace, Kansas, US
# Getting Data for city:  Washington, Kansas, US
# Getting Data for city:  Wichita, Kansas, US
# Getting Data for city:  Wilson, Kansas, US
# Getting Data for city:  Woodson, Kansas, US
# Getting Data for city:  Wyandotte, Kansas, US
# Getting Data for city:  Adair, Kentucky, US
# Getting Data for city:  Allen, Kentucky, US
# Getting Data for city:  Anderson, Kentucky, US
# Getting Data for city:  Ballard, Kentucky, US
# Getting Data for city:  Barren, Kentucky, US
# Getting Data for city:  Bath, Kentucky, US
# Getting Data for city:  Bell, Kentucky, US
# Getting Data for city:  Boone, Kentucky, US
# Getting Data for city:  Bourbon, Kentucky, US
# Getting Data for city:  Boyd, Kentucky, US
# Getting Data for city:  Boyle, Kentucky, US
# Getting Data for city:  Bracken, Kentucky, US
# Getting Data for city:  Breathitt, Kentucky, US
# Getting Data for city:  Breckinridge, Kentucky, US
# Getting Data for city:  Bullitt, Kentucky, US
# Getting Data for city:  Butler, Kentucky, US
# Getting Data for city:  Caldwell, Kentucky, US
# Getting Data for city:  Calloway, Kentucky, US
# Getting Data for city:  Campbell, Kentucky, US
# Getting Data for city:  Carlisle, Kentucky, US
# Getting Data for city:  Carroll, Kentucky, US
# Getting Data for city:  Carter, Kentucky, US
# Getting Data for city:  Casey, Kentucky, US
# Getting Data for city:  Christian, Kentucky, US
# Getting Data for city:  Clark, Kentucky, US
# Getting Data for city:  Clay, Kentucky, US
# Getting Data for city:  Clinton, Kentucky, US
# Getting Data for city:  Crittenden, Kentucky, US
# Getting Data for city:  Cumberland, Kentucky, US
# Getting Data for city:  Daviess, Kentucky, US
# Getting Data for city:  Edmonson, Kentucky, US
# Getting Data for city:  Elliott, Kentucky, US
# Getting Data for city:  Estill, Kentucky, US
# Getting Data for city:  Fayette, Kentucky, US
# Getting Data for city:  Fleming, Kentucky, US
# Getting Data for city:  Floyd, Kentucky, US
# Getting Data for city:  Franklin, Kentucky, US
# Getting Data for city:  Fulton, Kentucky, US
# Getting Data for city:  Gallatin, Kentucky, US
# Getting Data for city:  Garrard, Kentucky, US
# Getting Data for city:  Grant, Kentucky, US
# Getting Data for city:  Graves, Kentucky, US
# Getting Data for city:  Grayson, Kentucky, US
# Getting Data for city:  Green, Kentucky, US
# Getting Data for city:  Greenup, Kentucky, US
# Getting Data for city:  Hancock, Kentucky, US
# Getting Data for city:  Hardin, Kentucky, US
# Getting Data for city:  Harlan, Kentucky, US
# Getting Data for city:  Harrison, Kentucky, US
# Getting Data for city:  Hart, Kentucky, US
# Getting Data for city:  Henderson, Kentucky, US
# Getting Data for city:  Henry, Kentucky, US
# Getting Data for city:  Hickman, Kentucky, US
# Getting Data for city:  Hopkins, Kentucky, US
# Getting Data for city:  Jackson, Kentucky, US
# Getting Data for city:  Jefferson, Kentucky, US
# Getting Data for city:  Jessamine, Kentucky, US
# Getting Data for city:  Johnson, Kentucky, US
# Getting Data for city:  Kenton, Kentucky, US
# Getting Data for city:  Knott, Kentucky, US
# Getting Data for city:  Knox, Kentucky, US
# Getting Data for city:  Larue, Kentucky, US
# Getting Data for city:  Laurel, Kentucky, US
# Getting Data for city:  Lawrence, Kentucky, US
# Getting Data for city:  Lee, Kentucky, US
# Getting Data for city:  Leslie, Kentucky, US
# Getting Data for city:  Letcher, Kentucky, US
# Getting Data for city:  Lewis, Kentucky, US
# Getting Data for city:  Lincoln, Kentucky, US
# Getting Data for city:  Livingston, Kentucky, US
# Getting Data for city:  Logan, Kentucky, US
# Getting Data for city:  Lyon, Kentucky, US
# Getting Data for city:  McCracken, Kentucky, US
# Getting Data for city:  McCreary, Kentucky, US
# Getting Data for city:  McLean, Kentucky, US
# Getting Data for city:  Madison, Kentucky, US
# ...
# Getting Data for city:  Fredericksburg, Virginia, US
# Getting Data for city:  Galax, Virginia, US
# Getting Data for city:  Hampton, Virginia, US
# Getting Data for city:  Harrisonburg, Virginia, US
# Getting Data for city:  Hopewell, Virginia, US
# Getting Data for city:  Lexington, Virginia, US
# Getting Data for city:  Lynchburg, Virginia, US
# Getting Data for city:  Manassas,Virginia,US
# Getting Data for city:  Manassas Park, Virginia, US
# Getting Data for city:  Martinsville, Virginia, US
# Getting Data for city:  Newport News, Virginia, US
# Getting Data for city:  Norfolk, Virginia, US
# Getting Data for city:  Norton, Virginia, US
# Getting Data for city:  Petersburg, Virginia, US
# Getting Data for city:  Poquoson, Virginia, US
# Getting Data for city:  Portsmouth, Virginia, US
# Getting Data for city:  Radford, Virginia, US
# Getting Data for city:  Richmond City, Virginia, US
# Getting Data for city:  Roanoke City, Virginia, US
# Getting Data for city:  Salem, Virginia, US
# Getting Data for city:  Staunton, Virginia, US
# Getting Data for city:  Suffolk, Virginia, US
# Getting Data for city:  Virginia Beach, Virginia, US
# Getting Data for city:  Waynesboro, Virginia, US
# Getting Data for city:  Williamsburg, Virginia, US
# Getting Data for city:  Winchester, Virginia, US
# Getting Data for city:  Adams, Washington, US
# Getting Data for city:  Asotin, Washington, US
# Getting Data for city:  Benton, Washington, US
# Getting Data for city:  Chelan, Washington, US
# Getting Data for city:  Clallam, Washington, US
# Getting Data for city:  Clark, Washington, US
# Getting Data for city:  Columbia, Washington, US
# Getting Data for city:  Cowlitz, Washington, US
# Getting Data for city:  Douglas, Washington, US
# Getting Data for city:  Ferry, Washington, US
# Getting Data for city:  Franklin, Washington, US
# Getting Data for city:  Garfield, Washington, US
# Getting Data for city:  Grant, Washington, US
# Getting Data for city:  Grays Harbor, Washington, US
# Getting Data for city:  Island, Washington, US
# Getting Data for city:  Jefferson, Washington, US
# Getting Data for city:  King, Washington, US
# Getting Data for city:  Kitsap, Washington, US
# Getting Data for city:  Kittitas, Washington, US
# Getting Data for city:  Klickitat, Washington, US
# Getting Data for city:  Lewis, Washington, US
# Getting Data for city:  Lincoln, Washington, US
# Getting Data for city:  Mason, Washington, US
# Getting Data for city:  Okanogan, Washington, US
# Getting Data for city:  Pacific, Washington, US
# Getting Data for city:  Pend Oreille, Washington, US
# Getting Data for city:  Pierce, Washington, US
# Getting Data for city:  San Juan, Washington, US
# Getting Data for city:  Skagit, Washington, US
# Getting Data for city:  Skamania, Washington, US
# Getting Data for city:  Snohomish, Washington, US
# Getting Data for city:  Spokane, Washington, US
# Getting Data for city:  Stevens, Washington, US
# Getting Data for city:  Thurston, Washington, US
# Getting Data for city:  Wahkiakum, Washington, US
# Getting Data for city:  Walla Walla, Washington, US
# Getting Data for city:  Whatcom, Washington, US
# Getting Data for city:  Whitman, Washington, US
# Getting Data for city:  Yakima, Washington, US
# Getting Data for city:  Barbour, West Virginia, US
# Getting Data for city:  Berkeley, West Virginia, US
# Getting Data for city:  Boone, West Virginia, US
# Getting Data for city:  Braxton, West Virginia, US
# Getting Data for city:  Brooke, West Virginia, US
# Getting Data for city:  Cabell, West Virginia, US
# Getting Data for city:  Calhoun, West Virginia, US
# Getting Data for city:  Clay, West Virginia, US
# Getting Data for city:  Doddridge, West Virginia, US
# Getting Data for city:  Fayette, West Virginia, US
# Getting Data for city:  Gilmer, West Virginia, US
# Getting Data for city:  Grant, West Virginia, US
# Getting Data for city:  Greenbrier, West Virginia, US
# Getting Data for city:  Hampshire, West Virginia, US
# Getting Data for city:  Hancock, West Virginia, US
# Getting Data for city:  Hardy, West Virginia, US
# Getting Data for city:  Harrison, West Virginia, US
# Getting Data for city:  Jackson, West Virginia, US
# Getting Data for city:  Jefferson, West Virginia, US
# Getting Data for city:  Kanawha, West Virginia, US
# Getting Data for city:  Lewis, West Virginia, US
# Getting Data for city:  Lincoln, West Virginia, US
# Getting Data for city:  Logan, West Virginia, US
# Getting Data for city:  McDowell, West Virginia, US
# Getting Data for city:  Marion, West Virginia, US
# Getting Data for city:  Marshall, West Virginia, US
# Getting Data for city:  Mason, West Virginia, US
# Getting Data for city:  Mercer, West Virginia, US
# Getting Data for city:  Mineral, West Virginia, US
# Getting Data for city:  Mingo, West Virginia, US
# Getting Data for city:  Monongalia, West Virginia, US
# Getting Data for city:  Monroe, West Virginia, US
# Getting Data for city:  Morgan, West Virginia, US
# Getting Data for city:  Nicholas, West Virginia, US
# Getting Data for city:  Ohio, West Virginia, US
# Getting Data for city:  Pendleton, West Virginia, US
# Getting Data for city:  Pleasants, West Virginia, US
# Getting Data for city:  Pocahontas, West Virginia, US
# Getting Data for city:  Preston, West Virginia, US
# Getting Data for city:  Putnam, West Virginia, US
# Getting Data for city:  Raleigh, West Virginia, US
# Getting Data for city:  Randolph, West Virginia, US
# Getting Data for city:  Ritchie, West Virginia, US
# Getting Data for city:  Roane, West Virginia, US
# Getting Data for city:  Summers, West Virginia, US
# Getting Data for city:  Taylor, West Virginia, US
# Getting Data for city:  Tucker, West Virginia, US
# Getting Data for city:  Tyler, West Virginia, US
# Getting Data for city:  Upshur, West Virginia, US
# Getting Data for city:  Wayne, West Virginia, US
# Getting Data for city:  Webster, West Virginia, US
# Getting Data for city:  Wetzel, West Virginia, US
# Getting Data for city:  Wirt, West Virginia, US
# Getting Data for city:  Wood, West Virginia, US
# Getting Data for city:  Wyoming, West Virginia, US
# Getting Data for city:  Adams, Wisconsin, US
# Getting Data for city:  Ashland, Wisconsin, US
# Getting Data for city:  Barron, Wisconsin, US
# Getting Data for city:  Bayfield, Wisconsin, US
# Getting Data for city:  Brown, Wisconsin, US
# Getting Data for city:  Buffalo, Wisconsin, US
# Getting Data for city:  Burnett, Wisconsin, US
# Getting Data for city:  Calumet, Wisconsin, US
# Getting Data for city:  Chippewa, Wisconsin, US
# Getting Data for city:  Clark, Wisconsin, US
# Getting Data for city:  Columbia, Wisconsin, US
# Getting Data for city:  Crawford, Wisconsin, US
# Getting Data for city:  Dane, Wisconsin, US
# Getting Data for city:  Dodge, Wisconsin, US
# Getting Data for city:  Door, Wisconsin, US
# Getting Data for city:  Douglas, Wisconsin, US
# Getting Data for city:  Dunn, Wisconsin, US
# Getting Data for city:  Eau Claire, Wisconsin, US
# Getting Data for city:  Florence, Wisconsin, US
# Getting Data for city:  Fond du Lac, Wisconsin, US
# Getting Data for city:  Forest, Wisconsin, US
# Getting Data for city:  Grant, Wisconsin, US
# Getting Data for city:  Green, Wisconsin, US
# Getting Data for city:  Green Lake, Wisconsin, US
# Getting Data for city:  Platte, Wyoming, US
# Getting Data for city:  Sheridan, Wyoming, US
# Getting Data for city:  Sublette, Wyoming, US
# Getting Data for city:  Sweetwater, Wyoming, US
# Getting Data for city:  Teton, Wyoming, US
# Getting Data for city:  Uinta, Wyoming, US
# Getting Data for city:  Washakie, Wyoming, US
# Getting Data for city:  Weston, Wyoming, US
# Getting Data for city:  Out of AL, Alabama, US
# Getting Data for city:  Out of AK, Alaska, US
# Getting Data for city:  Out of AZ, Arizona, US
# Getting Data for city:  Out of AR, Arkansas, US
# Getting Data for city:  Out of CA, California, US
# Getting Data for city:  Out of CO, Colorado, US
# Getting Data for city:  Out of CT, Connecticut, US
# Getting Data for city:  Out of DE, Delaware, US
# Getting Data for city:  Out of DC, District of Columbia, US
# Getting Data for city:  Out of FL, Florida, US
# Getting Data for city:  Out of GA, Georgia, US
# Getting Data for city:  Out of HI, Hawaii, US
# Getting Data for city:  Out of ID, Idaho, US
# Getting Data for city:  Out of IL, Illinois, US
# Getting Data for city:  Out of IN, Indiana, US
# Getting Data for city:  Out of IA, Iowa, US
# Getting Data for city:  Out of KS, Kansas, US
# Getting Data for city:  Out of KY, Kentucky, US
# Getting Data for city:  Out of LA, Louisiana, US
# Getting Data for city:  Out of ME, Maine, US
# Getting Data for city:  Out of MD, Maryland, US
# Getting Data for city:  Out of MA, Massachusetts, US
# Getting Data for city:  Out of MI, Michigan, US
# Getting Data for city:  Out of MN, Minnesota, US
# Getting Data for city:  Out of MS, Mississippi, US
# Getting Data for city:  Out of MO, Missouri, US
# Getting Data for city:  Out of MT, Montana, US
# Getting Data for city:  Out of NE, Nebraska, US
# Getting Data for city:  Out of NV, Nevada, US
# Getting Data for city:  Out of NH, New Hampshire, US
# Getting Data for city:  Out of NJ, New Jersey, US
# Getting Data for city:  Out of NM, New Mexico, US
# Getting Data for city:  Out of NY, New York, US
# Getting Data for city:  Out of NC, North Carolina, US
# Getting Data for city:  Out of ND, North Dakota, US
# Getting Data for city:  Out of OH, Ohio, US
# Getting Data for city:  Out of OK, Oklahoma, US
# Getting Data for city:  Out of OR, Oregon, US
# Getting Data for city:  Out of PA, Pennsylvania, US
# Getting Data for city:  Out of RI, Rhode Island, US
# Getting Data for city:  Out of SC, South Carolina, US
# Getting Data for city:  Out of SD, South Dakota, US
# Getting Data for city:  Out of TN, Tennessee, US
# Getting Data for city:  Out of TX, Texas, US
# Getting Data for city:  Out of UT, Utah, US
# Getting Data for city:  Out of VT, Vermont, US
# Getting Data for city:  Out of VA, Virginia, US
# Getting Data for city:  Out of WA, Washington, US
# Getting Data for city:  Out of WV, West Virginia, US
# Getting Data for city:  Out of WI, Wisconsin, US
# Getting Data for city:  Out of WY, Wyoming, US
# Getting Data for city:  Diamond Princess, US
# Getting Data for city:  Unassigned, Alabama, US
# Getting Data for city:  Unassigned, Alaska, US
# Getting Data for city:  Unassigned, Arizona, US
# Getting Data for city:  Unassigned, Arkansas, US
# Getting Data for city:  Unassigned, California, US
# Getting Data for city:  Unassigned, Colorado, US
# Getting Data for city:  Unassigned, Connecticut, US
# Getting Data for city:  Unassigned, Delaware, US
# Getting Data for city:  Unassigned, District of Columbia, US
# Getting Data for city:  Unassigned, Florida, US
# Getting Data for city:  Unassigned, Georgia, US
# Getting Data for city:  Unassigned, Hawaii, US
# Getting Data for city:  Unassigned, Idaho, US
# Getting Data for city:  Unassigned, Illinois, US
# Getting Data for city:  Unassigned, Indiana, US
# Getting Data for city:  Unassigned, Iowa, US
# Getting Data for city:  Unassigned, Kansas, US
# Getting Data for city:  Unassigned, Kentucky, US
# Getting Data for city:  Unassigned, Louisiana, US
# Getting Data for city:  Unassigned, Maine, US
# Getting Data for city:  Unassigned, Maryland, US
# Getting Data for city:  Unassigned, Massachusetts, US
# Getting Data for city:  Unassigned, Michigan, US
# Getting Data for city:  Unassigned, Minnesota, US
# Getting Data for city:  Unassigned, Mississippi, US
# Getting Data for city:  Unassigned, Missouri, US
# Getting Data for city:  Unassigned, Montana, US
# Getting Data for city:  Unassigned, Nebraska, US
# Getting Data for city:  Unassigned, Nevada, US
# Getting Data for city:  Unassigned, New Hampshire, US
# Getting Data for city:  Unassigned, New Jersey, US
# Getting Data for city:  Unassigned, New Mexico, US
# Getting Data for city:  Unassigned, New York, US
# Getting Data for city:  Unassigned, North Carolina, US
# Getting Data for city:  Unassigned, North Dakota, US
# Getting Data for city:  Unassigned, Ohio, US
# Getting Data for city:  Unassigned, Oklahoma, US
# Getting Data for city:  Unassigned, Oregon, US
# Getting Data for city:  Unassigned, Pennsylvania, US
# Getting Data for city:  Unassigned, Rhode Island, US
# Getting Data for city:  Unassigned, South Carolina, US
# Getting Data for city:  Unassigned, South Dakota, US
# Getting Data for city:  Unassigned, Tennessee, US
# Getting Data for city:  Unassigned, Texas, US
# Getting Data for city:  Unassigned, Utah, US
# Getting Data for city:  Unassigned, Vermont, US
# Getting Data for city:  Unassigned, Virginia, US
# Getting Data for city:  Unassigned, Washington, US
# Getting Data for city:  Unassigned, West Virginia, US
# Getting Data for city:  Unassigned, Wisconsin, US
# Getting Data for city:  Unassigned, Wyoming, US
# Getting Data for city:  Grand Princess, US
# Getting Data for city:  Dukes and Nantucket,Massachusetts,US
# Getting Data for city:  Kansas City,Missouri,US
# Getting Data for city:  Michigan Department of Corrections (MDOC), Michigan, US
# Getting Data for city:  Federal Correctional Institution (FCI), Michigan, US
# Getting Data for city:  Bear River, Utah, US
# Getting Data for city:  Central Utah, Utah, US
# Getting Data for city:  Southeast Utah, Utah, US
# Getting Data for city:  Southwest Utah, Utah, US
# Getting Data for city:  TriCounty, Utah, US
# Getting Data for city:  Weber-Morgan, Utah, US

# %%
import statsmodels.tsa.stattools as sts

# %% [markdown]
# There are a number of unit root tests and the Augmented Dickey-Fuller may be one of the more widely used. It uses an autoregressive model and optimizes an information criterion across multiple different lag values.
#
# The null hypothesis of the test is that the time series can be represented by a unit root, that it is not stationary (has some time-dependent structure). The alternate hypothesis (rejecting the null hypothesis) is that the time series is stationary.
#
# Null Hypothesis (H0): If failed to be rejected, it suggests the time series has a unit root, meaning it is non-stationary. It has some time dependent structure.
# Alternate Hypothesis (H1): The null hypothesis is rejected; it suggests the time series does not have a unit root, meaning it is stationary. It does not have time-dependent structure.
# We interpret this result using the p-value from the test. A p-value below a threshold (such as 5% or 1%) suggests we reject the null hypothesis (stationary), otherwise a p-value above the threshold suggests we fail to reject the null hypothesis (non-stationary).
#
# * p-value > 0.05: Fail to reject the null hypothesis (H0), the data has a unit root and is non-stationary.
# * p-value <= 0.05: Reject the null hypothesis (H0), the data does not have a unit root and is stationary.
#
# source: [How to Check if Time Series Data is Stationary with Python](https://machinelearningmastery.com/time-series-data-stationary-python/)

# %%
def getStationarity(df, n=5, start_Date='2020-01-22'):
    ts, cities = getRandomAsTS(df,n,start_Date)
    #print(ts[0])
    df_return = pd.DataFrame() 
    arr_city = []
    arr_adf = []
    arr_p_value = []
    arr_1 =[]
    arr_5 = []
    arr_10 = []
    
    threshold = 0.05
    #print("\n\n")
    for city in range(len(cities)):
        try:
            adfuller_results = sts.adfuller(ts[city])
            arr_city.append(cities[city])
            arr_adf.append(adfuller_results[0])
            arr_p_value.append(adfuller_results[1])
            #print('Critical Values:')
            arr_1.append(adfuller_results[4]['1%'])
            arr_1.append(adfuller_results[4]['5%'])
            arr_1.append(adfuller_results[4]['10%'])
            #print("\n\n")
        except:
            print("An occurred with city: ", cities[city])
    print(arr_1)
    df_return['City'] = arr_city
    df_return['adf'] = arr_adf
    df_return['p-value'] = arr_p_value
    #df_return['significance_1'] = arr_1
    #df_return['significance_5'] = arr_5
    #df_return['significance_10'] = arr_10
    return df_return
    
def printStationarity(df, n=5, start_Date='2020-01-22'):
    ts, cities = getRandomAsTS(df,n,start_Date)
    #print(ts[0])
    threshold = 0.05
    print("\n\n")
    for city in range(len(cities)):
        try:
            adfuller_results = sts.adfuller(ts[city])
            print(adfuller_results)
            print("adfuller for: ", cities[city])
            print('ADF Statistic: %f' % adfuller_results[0])
            print('p-value: %f' % adfuller_results[1])
            print('Critical Values:')
            #print(adfuller_results[4])
            for key, value in adfuller_results[4].items():
                print('\t%s: %.3f' % (key, value))
            print("\n\n")
        except:
            print("An occurred with city: ", cities[city])

# %%
getStationarity(covid_df,5,'2020-04-01').head()
# Out:
# Selected cities:  ['Colfax, New Mexico, US', 'Shelby, Missouri, US', 'Lebanon, Pennsylvania, US', 'Russell, Alabama, US', 'Unassigned, South Dakota, US']
# Getting Data for city:  Colfax, New Mexico, US
# Getting Data for city:  Shelby, Missouri, US
# Getting Data for city:  Lebanon, Pennsylvania, US
# Getting Data for city:  Russell, Alabama, US
# Getting Data for city:  Unassigned, South Dakota, US
# -3.517113604831504
#                            City       adf   p-value
# 0        Colfax, New Mexico, US -0.771809  0.827263
# 1          Shelby, Missouri, US -0.158139  0.943331
# 2     Lebanon, Pennsylvania, US -3.335473  0.013365
# 3          Russell, Alabama, US  2.813154  1.000000
# 4  Unassigned, South Dakota, US -4.446441  0.000245
